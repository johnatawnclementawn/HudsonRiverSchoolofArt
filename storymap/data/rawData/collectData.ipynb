# %% [markdown]
# collectData.py
# Johnathan Clementi
# March, 2022
#
# This script gathers data used to make the Hudson River School of Art mapper and visualizer webpage

# %%
from bs4 import BeautifulSoup
import urllib
import regex as re
import requests
import pandas as pd
import numpy as np
import json
import os

# %%
path = os.getcwd()

# The url to pull data from:
url = "https://en.wikipedia.org/wiki/List_of_Hudson_River_School_artists"

df = pd.read_html(url)[0]
# df

# %%
# https://stackoverflow.com/questions/56757261/extract-href-using-pandas-read-html

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table')

linkNames = []
artistNames = []
links = []
for tr in table.findAll("tr"):
    trs = tr.findAll("td")
    for each in trs:
        try:
            linkName = each.find("a", attrs={"class":"extiw"})
            if type(linkName) != type(None):
                # linkNames.append(linkName) # Append whole BS4 object to list
                
                # Parse out links
                pageLink = re.sub("^.*href=\"","", str(linkName))
                pageLink = re.sub("\".*", "", pageLink, count=0)
                links.append(pageLink)

                pageName = re.sub("^.*Category:", "", str(linkName))
                pageName = re.sub("\">.*", "", pageName, count=0)
                artistNames.append(pageName)
        except:
            pass

# linkNames = list(filter(None, linkNames)) # Remove None from list

# Compress into a df
wikiArtistPgs = pd.DataFrame(artistNames)
wikiArtistPgs.columns = ['artist_name']
wikiArtistPgs['content_link'] = links
# wikiArtistPgs['BS4_return'] = linkNames
wikiArtistPgs

# %%
wikiImages = []
# sep = "jpg" # Use 'jpg' to splice out url for full res images

for link in links:
  response = requests.get(link)
  soup = BeautifulSoup(response.text, 'html.parser')
  galleryBox = soup.findAll("li", attrs={"class":"gallerybox"})
  # galleryText = soup.findAll("div", attrs={"class":"gallerytext"})

  for box in galleryBox:
    img = box.findAll("a", attrs={"class":"image"})
    imgLink = re.sub("^.*src=\"", "", str(img), count=0)
    imgLink = re.sub("\/thumb", "", imgLink, count=0)
    # imgLink, sp, tail = imgLink.partition(sep)
    # imgLink = imgLink + sep # Add separator back in
    imgLink = imgLink.split("(jpg|gif|png)")[0]
    print(imgLink)
    print("\n")

  # for txt in galleryText:
  #   pageLink = txt.find("a", attrs={"class":"galleryfilename galleryfilename-truncate"})
  #   pageLink = re.sub("^.*href=\"","", str(pageLink))
  #   pageLink = re.sub("\".*", "", pageLink, count=0)
  #   pageLink = "https://commons.wikimedia.org{}".format(pageLink)
  #   print(pageLink)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/b/bf/Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg/120px-Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/b/bf/Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg/180px-Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/b/bf/Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg/240px-Baker%2C_Charles_-_Sunset_by_the_Lake_%281849%29.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/c/ca/Charles_Baker_River_Landscape_with_Cattle.png/120px-Charles_Baker_River_Landscape_with_Cattle.png" srcset="https://upload.wikimedia.org/wikipedia/commons/c/ca/Charles_Baker_River_Landscape_with_Cattle.png/180px-Charles_Baker_River_Landscape_with_Cattle.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/c/ca/Charles_Baker_River_Landscape_with_Cattle.png/240px-Charles_Baker_River_Landscape_with_Cattle.png 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/8/81/Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg/85px-Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/8/81/Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg/128px-Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/8/81/Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg/171px-Charles_Baker_and_others_near_the_elevator_to_the_excavated_chamber_to_the_powerhouse%2C_ca_1900_%28SPWS_309%29.jpg 2x" width="85"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/e/e8/Baker_Silence_Art_of_World_vol.6.jpg/120px-Baker_Silence_Art_of_World_vol.6.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/e/e8/Baker_Silence_Art_of_World_vol.6.jpg/180px-Baker_Silence_Art_of_World_vol.6.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/e/e8/Baker_Silence_Art_of_World_vol.6.jpg/240px-Baker_Silence_Art_of_World_vol.6.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/3/30/Shadows_in_a_Pool_by_William_Bliss_Baker.jpg/120px-Shadows_in_a_Pool_by_William_Bliss_Baker.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/3/30/Shadows_in_a_Pool_by_William_Bliss_Baker.jpg/180px-Shadows_in_a_Pool_by_William_Bliss_Baker.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/3/30/Shadows_in_a_Pool_by_William_Bliss_Baker.jpg/240px-Shadows_in_a_Pool_by_William_Bliss_Baker.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/3/34/Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg/120px-Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/3/34/Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg/180px-Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/3/34/Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg/240px-Woodland_Scene_by_William_Bliss_Baker%2C_1885.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/5/53/Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg/120px-Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/5/53/Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg/180px-Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/5/53/Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg/240px-Fallen_Monarchs_1886_by_William_Bliss_Baker.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/f/fd/Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg/120px-Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/f/fd/Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg/180px-Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/f/fd/Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg/240px-Hiding_in_the_Haycocks_%281881%29_by_William_Bliss_Baker.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/e/e7/Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg/120px-Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/e/e7/Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg/180px-Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/e/e7/Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg/240px-Landscape_Grez_by_William_Bliss_Baker_ca1882_-_from_Horace_C_Henry_Collection_at_Henry_Art_Gallery_University_of_Washington.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/d/d4/The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf/page1-81px-The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/d/d4/The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf/page1-121px-The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/d/d4/The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf/page1-161px-The_Works_of_Wm._Bliss_Baker%2C_Dec%27d_-_1887.pdf.jpg 2x" width="81"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/a/ad/William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png/93px-William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png" srcset="https://upload.wikimedia.org/wikipedia/commons/a/ad/William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png/139px-William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png 1.5x, https://upload.wikimedia.org/wikipedia/commons/a/ad/William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png/186px-William_Bliss_Baker_-_engraving_from_Harper%27s_Weekly_1886_by_Harper_and_Brothers.png 2x" width="93"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/1/1e/William_Bliss_Baker_Dark_Forest_ca.1880.jpg/98px-William_Bliss_Baker_Dark_Forest_ca.1880.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/1/1e/William_Bliss_Baker_Dark_Forest_ca.1880.jpg/147px-William_Bliss_Baker_Dark_Forest_ca.1880.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/1/1e/William_Bliss_Baker_Dark_Forest_ca.1880.jpg/197px-William_Bliss_Baker_Dark_Forest_ca.1880.jpg 2x" width="98"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/0/02/William_Bliss_Baker_Grave_1.jpg/120px-William_Bliss_Baker_Grave_1.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/0/02/William_Bliss_Baker_Grave_1.jpg/180px-William_Bliss_Baker_Grave_1.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/0/02/William_Bliss_Baker_Grave_1.jpg/240px-William_Bliss_Baker_Grave_1.jpg 2x" width="120"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/5/5e/William_Bliss_Baker_Grave_2.jpg/80px-William_Bliss_Baker_Grave_2.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/5/5e/William_Bliss_Baker_Grave_2.jpg/120px-William_Bliss_Baker_Grave_2.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/5/5e/William_Bliss_Baker_Grave_2.jpg/160px-William_Bliss_Baker_Grave_2.jpg 2x" width="80"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/9/91/William_Bliss_Baker_Grave_3.jpg/80px-William_Bliss_Baker_Grave_3.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/9/91/William_Bliss_Baker_Grave_3.jpg/120px-William_Bliss_Baker_Grave_3.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/9/91/William_Bliss_Baker_Grave_3.jpg/160px-William_Bliss_Baker_Grave_3.jpg 2x" width="80"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/a/af/William_Bliss_Baker_photo.jpg/92px-William_Bliss_Baker_photo.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/a/af/William_Bliss_Baker_photo.jpg/139px-William_Bliss_Baker_photo.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/a/af/William_Bliss_Baker_photo.jpg/185px-William_Bliss_Baker_photo.jpg 2x" width="92"/></a>]
#
#
# https://upload.wikimedia.org/wikipedia/commons/d/d8/Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg/90px-Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg" srcset="https://upload.wikimedia.org/wikipedia/commons/d/d8/Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg/135px-Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg 1.5x, https://upload.wikimedia.org/wikipedia/commons/d/d8/Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg/180px-Skaneateles_Library_and_John_D._Barrow_Art_Gallery_detail.jpg 2x" width="90"/></a>]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Users\Johnathan\Google Drive\Grad School\Penn_MUSA\Spring2022\611_JavaScript\HudsonRiverSchoolofArt\storymap\data\rawData\collectData.ipynb Cell 5' in <cell line: 4>()
#      <a href='vscode-notebook-cell:/d%3A/Users/Johnathan/Google%20Drive/Grad%20School/Penn_MUSA/Spring2022/611_JavaScript/HudsonRiverSchoolofArt/storymap/data/rawData/collectData.ipynb#ch0000013?line=13'>14</a> # imgLink, sp, tail = imgLink.partition(sep)
#      <a href='vscode-notebook-cell:/d%3A/Users/Johnathan/Google%20Drive/Grad%20School/Penn_MUSA/Spring2022/611_JavaScript/HudsonRiverSchoolofArt/storymap/data/rawData/collectData.ipynb#ch0000013?line=14'>15</a> # imgLink = imgLink + sep # Add separator back in
#      <a href='vscode-notebook-cell:/d%3A/Users/Johnathan/Google%20Drive/Grad%20School/Penn_MUSA/Spring2022/611_JavaScript/HudsonRiverSchoolofArt/storymap/data/rawData/collectData.ipynb#ch0000013?line=15'>16</a> imgLink = imgLink.split("(jpg|gif|png)")[0]
# ---> <a href='vscode-notebook-cell:/d%3A/Users/Johnathan/Google%20Drive/Grad%20School/Penn_MUSA/Spring2022/611_JavaScript/HudsonRiverSchoolofArt/storymap/data/rawData/collectData.ipynb#ch0000013?line=16'>17</a> print(imgLink)
#      <a href='vscode-notebook-cell:/d%3A/Users/Johnathan/Google%20Drive/Grad%20School/Penn_MUSA/Spring2022/611_JavaScript/HudsonRiverSchoolofArt/storymap/data/rawData/collectData.ipynb#ch0000013?line=17'>18</a> print("\n")
#
# File ~\Anaconda3\envs\musa650_HW2\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=528'>529</a> is_child = (not self._is_master_process())
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=529'>530</a> # only touch the buffer in the IO thread to avoid races
# --> <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=530'>531</a> self.pub_thread.schedule(lambda: self._buffer.write(string))
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=531'>532</a> if is_child:
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=532'>533</a>     # mp.Pool cannot be trusted to flush promptly (or ever),
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=533'>534</a>     # and this helps.
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=534'>535</a>     if self._subprocess_flush_pending:
#
# File ~\Anaconda3\envs\musa650_HW2\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=213'>214</a>     self._events.append(f)
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=214'>215</a>     # wake event thread (message content is ignored)
# --> <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=215'>216</a>     self._event_pipe.send(b'')
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=216'>217</a> else:
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/ipykernel/iostream.py?line=217'>218</a>     f()
#
# File ~\Anaconda3\envs\musa650_HW2\lib\site-packages\zmq\sugar\socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=539'>540</a>         data = zmq.Frame(
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=540'>541</a>             data,
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=541'>542</a>             track=track,
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=542'>543</a>             copy=copy or None,
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=543'>544</a>             copy_threshold=self.copy_threshold,
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=544'>545</a>         )
#     <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=545'>546</a>     data.group = group
# --> <a href='file:///c%3A/Users/Johnathan/Anaconda3/envs/musa650_HW2/lib/site-packages/zmq/sugar/socket.py?line=546'>547</a> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~\Anaconda3\envs\musa650_HW2\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# # empty list
# data = []
# list_header = []

# header = soup.find_all("table")[0].find("tr")
  
# for items in header:
#     try:
#         list_header.append(items.get_text())
#     except:
#         continue
  
# # for getting the data 
# HTML_data = soup.find_all("table")[0].find_all("tr")[1:]
  
# for element in HTML_data:
#     sub_data = []
#     for sub_element in element:
#         try:
#             sub_data.append(sub_element.get_text())
#         except:
#             continue
#     data.append(sub_data)
  
# # Storing the data into Pandas
# # DataFrame 
# dataFrame = pd.DataFrame(data = data, columns = list_header)

# %%
# The url to pull data from:
url = "https://www.hudsonriverschool.org/hudsonrivervalley"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
h3s = soup.findAll('h3')
h3s = np.asarray(h3s)
# Out:
# C:\Users\Johnathan\AppData\Local\Temp\ipykernel_15820\1010148947.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   h3s = np.asarray(h3s)

# %%
sites = []

for site in h3s:
  site = str(site)
  siteName = re.search("\;\"\>.*(\<br\/\>){1}", site)
  siteName = re.sub("^.*;\">", "", str(siteName))
  siteName = re.sub("<.*", "", str(siteName))
  if siteName != "None":
    sites.append(siteName)

sitesDF = pd.DataFrame(sites)
sitesDF.columns = ['SiteName']
# sitesDF

# %%
subpages = soup.findAll('div', attrs={"class":"intrinsic"})
# str(subpages[2])

pgLinks = []

for page in subpages:
  page = str(page)
  pageLink = re.search("href=\"\/.*\"", page)
  pageLink = re.sub("^.*match='href=\"","", str(pageLink))
  pageLink = re.sub("\"\'>", "", pageLink)
  pageLink = "https://www.hudsonriverschool.org{}".format(pageLink)
  pgLinks.append(pageLink)

for i in range(3):
  pgLinks.pop()

# pgLinks

sitesDF['pageLink'] = pgLinks


sitesDF.to_csv('{}\\sitenames.csv'.format(path))

# %%
siteNames = []
siteCoords = []
long = []
lat = []

for url in pgLinks:
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')

  # Get site name from H2 elements in page
  h2s = soup.findAll('h2')
  for h2 in h2s:
    siteName = re.search("Site.*", str(h2))
    siteName = re.sub("^.*\#[0-9][0-9]*", "", str(siteName))
    siteName = re.sub("<\/h2>\'>", "", str(siteName))
    if siteName != "None":
      siteNames.append(siteName)

  # Get lat and long values from paragraph elements in the page
  ps = soup.findAll('p')
  for p in ps:
    pElement = str(p)
    coords = re.search("Site coordinates.*Long", pElement)
    latlong = re.sub("^.*match='","", str(coords))
    latlong = re.sub("\'>", "", latlong)
    if latlong != "None":
      siteCoords.append(latlong)

      lt = re.search("\: .*\, ", latlong)
      lt = re.sub("^.*match=\'\: ", "", str(lt))
      lt = re.sub(" Lat\.\, \'>", "", lt)
      lt = re.sub("\, \'>", "", lt)
      lat.append(lt)

      lng = re.search("\, .*Long", latlong)
      lng = re.sub("^.*match=\'\, ", "", str(lng))
      lng = re.sub(" Long\'>", "", lng)
      long.append(lng)

# %%
sitesLocDf = pd.DataFrame(siteNames)
sitesLocDf['siteCoords'] = siteCoords
sitesLocDf['lat'] = lat
sitesLocDf['long'] = long

# Write to csv
sitesLocDf.to_csv('{}\\siteloc.csv'.format(path))

# %%
siteImgs = []

for url in pgLinks:
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')

  # Get site name from H2 elements in page
  # h2s = soup.findAll('h2')
  # for h2 in h2s:
  #   siteName = re.search("Site.*", str(h2))
  #   siteName = re.sub("^.*\#[0-9][0-9]*", "", str(siteName))
  #   siteName = re.sub("<\/h2>\'>", "", str(siteName))
  #   if siteName != "None":
  #     siteNames.append(siteName)

  # Get images from each subpage
  imgs = soup.findAll('img')
  imgLink = re.search("src=\".*\"{1}", str(imgs))
  siteImgs.append(imgLink)
  # print(imgLink)

# %%
tst = str(siteImgs[0]).split(",")
for i in tst:
  print(i)
  print("#################################")
# Out:
# <regex.Match object; span=(68
# #################################
#  4821)
# #################################
#  match='src="//images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558972846717-OQ2U9Q8SISP0PTTJGRCQ/Art+Trail+insignia+3+color.png?format=1500w"/>
# #################################
#  <img alt="Hudson River Art Trail" class="Header-branding-logo" src="//images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558972846717-OQ2U9Q8SISP0PTTJGRCQ/Art+Trail+insignia+3+color.png?format=1500w"/>
# #################################
#  <img alt="Thomas_Cole_20180514_486_cover_art.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565033606712-NK99NT69U2617VHDBFNB/Thomas_Cole_20180514_486_cover_art.jpg"/>
# #################################
#  <img alt="Thomas_Cole_20180514_486_cover_art.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565033606712-NK99NT69U2617VHDBFNB/Thomas_Cole_20180514_486_cover_art.jpg" data-image-dimensions="1920x1280" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5d488481fb4ab200014f71f5" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565033606712-NK99NT69U2617VHDBFNB/Thomas_Cole_20180514_486_cover_art.jpg" data-type="image"/>
# #################################
#  <img alt="it_106.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985110797-Z0NA1LUXVWL9PXXZD3GP/it_106.jpg"/>
# #################################
#  <img alt="it_106.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985110797-Z0NA1LUXVWL9PXXZD3GP/it_106.jpg" data-image-dimensions="1000x653" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5cec3996e5e5f004c91cfdd8" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985110797-Z0NA1LUXVWL9PXXZD3GP/it_106.jpg" data-type="image"/>
# #################################
#  <img alt="it_3.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111063-I0OJYVQWTSLUFAQGE7JJ/it_3.jpg"/>
# #################################
#  <img alt="it_3.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111063-I0OJYVQWTSLUFAQGE7JJ/it_3.jpg" data-image-dimensions="1000x639" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5cec39964e17b65333e707e6" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111063-I0OJYVQWTSLUFAQGE7JJ/it_3.jpg" data-type="image"/>
# #################################
#  <img alt="it_369.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111532-CKHZU7UOFXS9TDVWNTSK/it_369.jpg"/>
# #################################
#  <img alt="it_369.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111532-CKHZU7UOFXS9TDVWNTSK/it_369.jpg" data-image-dimensions="1000x750" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5cec3996a4222f2d3d2b832c" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111532-CKHZU7UOFXS9TDVWNTSK/it_369.jpg" data-type="image"/>
# #################################
#  <img alt="it_359.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111610-F9AN9F4BMNDS943P2BL5/it_359.jpg"/>
# #################################
#  <img alt="it_359.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111610-F9AN9F4BMNDS943P2BL5/it_359.jpg" data-image-dimensions="853x1000" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5cec3997971a18139a4e52d4" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985111610-F9AN9F4BMNDS943P2BL5/it_359.jpg" data-type="image"/>
# #################################
#  <img alt="it_216.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985112083-SWOK7BESUQD598DFUOA0/it_216.jpg"/>
# #################################
#  <img alt="it_216.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985112083-SWOK7BESUQD598DFUOA0/it_216.jpg" data-image-dimensions="1000x653" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5cec3997c8302545b925ff92" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558985112083-SWOK7BESUQD598DFUOA0/it_216.jpg" data-type="image"/>
# #################################
#  <img alt="Art Trail insignia 3 color.png" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png"/>
# #################################
#  <img alt="Art Trail insignia 3 color.png" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png" data-image-dimensions="600x600" data-image-focal-point="0.5
# #################################
# 0.5" data-image-id="5ced64e44785d3e27069cfd1" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png" data-type="image"'>
# #################################

# %%
# Images from main page
imgs = soup.findAll('img')
imgs
# Out:
# [<img alt="Hudson River Art Trail" class="Mobile-bar-branding-logo" src="//images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558972846717-OQ2U9Q8SISP0PTTJGRCQ/Art+Trail+insignia+3+color.png?format=1500w"/>,
#  <img alt="Hudson River Art Trail" class="Header-branding-logo" src="//images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1558972846717-OQ2U9Q8SISP0PTTJGRCQ/Art+Trail+insignia+3+color.png?format=1500w"/>,
#  <img alt="Hudson_river_skywalk.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565036033975-W4LVIANFR5N89T931N3B/Hudson_river_skywalk.jpg"/>,
#  <img alt="Hudson_river_skywalk.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565036033975-W4LVIANFR5N89T931N3B/Hudson_river_skywalk.jpg" data-image-dimensions="2500x1875" data-image-focal-point="0.5,0.5" data-image-id="5d488e007ca5110001ba3da5" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1565036033975-W4LVIANFR5N89T931N3B/Hudson_river_skywalk.jpg" data-type="image"/>,
#  <img alt="it_547.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726109-H59JSB3XJ8XTWFVAJJRD/it_547.jpg"/>,
#  <img alt="it_547.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726109-H59JSB3XJ8XTWFVAJJRD/it_547.jpg" data-image-dimensions="855x1000" data-image-focal-point="0.5,0.5" data-image-id="5d092e25d7097700016fbf24" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726109-H59JSB3XJ8XTWFVAJJRD/it_547.jpg" data-type="image"/>,
#  <img alt="it_546.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882725910-R28VDPK6432B4YYNHF71/it_546.jpg"/>,
#  <img alt="it_546.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882725910-R28VDPK6432B4YYNHF71/it_546.jpg" data-image-dimensions="1000x476" data-image-focal-point="0.5,0.5" data-image-id="5d092e256555400001b16a82" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882725910-R28VDPK6432B4YYNHF71/it_546.jpg" data-type="image"/>,
#  <img alt="it_545.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726342-ZTKORKZK8KQ26TCH78DC/it_545.jpg"/>,
#  <img alt="it_545.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726342-ZTKORKZK8KQ26TCH78DC/it_545.jpg" data-image-dimensions="1000x627" data-image-focal-point="0.5,0.5" data-image-id="5d092e2604d44f0001346371" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726342-ZTKORKZK8KQ26TCH78DC/it_545.jpg" data-type="image"/>,
#  <img alt="it_544.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726408-TVGIDQU4VAJRPUFNVND7/it_544.jpg"/>,
#  <img alt="it_544.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726408-TVGIDQU4VAJRPUFNVND7/it_544.jpg" data-image-dimensions="500x354" data-image-focal-point="0.5,0.5" data-image-id="5d092e26c2341b0001fa34de" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560882726408-TVGIDQU4VAJRPUFNVND7/it_544.jpg" data-type="image"/>,
#  <img alt="HRS_web.jpg" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560967388284-14EDZ3JIR24W7FCJS8GF/HRS_web.jpg"/>,
#  <img alt="HRS_web.jpg" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560967388284-14EDZ3JIR24W7FCJS8GF/HRS_web.jpg" data-image-dimensions="1080x626" data-image-focal-point="0.5,0.5" data-image-id="5d0a78da5b4251000130d0b7" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1560967388284-14EDZ3JIR24W7FCJS8GF/HRS_web.jpg" data-type="image"/>,
#  <img alt="Art Trail insignia 3 color.png" src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png"/>,
#  <img alt="Art Trail insignia 3 color.png" class="thumb-image" data-image="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png" data-image-dimensions="600x600" data-image-focal-point="0.5,0.5" data-image-id="5ced64e44785d3e27069cfd1" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5cec0723a613da0001c31544/1559061732612-3OXVGPGI5UZQO7ZTI9IU/Art+Trail+insignia+3+color.png" data-type="image"/>]
